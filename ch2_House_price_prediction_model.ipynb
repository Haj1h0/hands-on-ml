# %% [markdown]
# <a href="https://colab.research.google.com/github/Haj1h0/hands-on-ml/blob/main/ch2_House_price_prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ha")
# Out:
# ha
